# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexTomagan/OOP-58001/blob/main/Fundamentals_of_Phyton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Phyton Identation

# %%
if 5.2:
  print("5 is greater than two!")
# Out:
# 5 is greater than two!

# %% [markdown]
# Comments

# %%
#This ia comment:
print("hello world")
# Out:
# hello world

# %% [markdown]
# Phyton Variable

# %%
x=1
a,b=0,-1
a,b,c =0,-1,2

# %% [markdown]
# Casting

# %%
b='sally' #this is a type of string:
b=int(4)
print(b)

b=float(4)
print(b)
# Out:
# 4
# 4.0

# %% [markdown]
# type()function

# %%
x=5
y="john"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# Case sensitive

# %%
a=4
A = "Sally"
#A will not overwrite a

# %% [markdown]
# Multiple variable

# %%
x,y,z = "one","two","three"
print(x)
print(y)
print(z)
# Out:
# one
# two
# three

# %% [markdown]
# One to Multiple Variable

# %%
x=y=z="four"
print(x)
print(y)
print(z)
# Out:
# four
# four
# four

# %% [markdown]
# Output Variable

# %%
x="enjoying"
print("Phyton programming is "+x)
# Out:
# Phyton programming is enjoying

# %% [markdown]
# Arithmethic Operations

# %%
f = 1
g = 2
o = 6

print (f+g) 
print (f-g)
print (f*g)
print (int(o/g))
print (3/g)
print (3%g)
print (3//g)
print (3**2)
print (2^6)
print (2**6)
# Out:
# 3
# -1
# 2
# 3
# 1.5
# 1
# 1
# 9
# 4
# 64

# %% [markdown]
# Assignment Operators

# %%
k = 2
k += 3 #same as k =k+3

print(3)
#print (k+=2)
# Out:
# 3

# %% [markdown]
# Comparison Operators

# %%
x==y
x!=y
x>y
x<y
x>=y
x<=y
# Out:
# True

# %% [markdown]
# Logical Operators

# %%
a,b,c=0,-1,6
a>b and c>b
# Out:
# True

# %% [markdown]
# Identity Operators

# %%
a,b,c=0,-1,5
a is c
# Out:
# False
