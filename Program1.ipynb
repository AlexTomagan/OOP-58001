# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexTomagan/OOP-58001/blob/main/Program1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def main():
 class TemperatureConversion:
  def __init__(self, temp=1):
   self._temp = temp
 class CelsiusToFahrenheit(TemperatureConversion):
  def conversion(self):
   return (self._temp * 9) / 5 + 32
 class FahrenheitToCelsius(TemperatureConversion):
   def conversion(self):
     return(self.temp) * 32 + 5 / 9
 class CelsiusToKelvin(TemperatureConversion):
  def conversion(self):
   return self._temp + 273.15
 class KelvinToCelsius(TemperatureConversion):
   def conversion(self):
    return self._temp - 273.15
 tempInCelsius = float(input("Enter the temperature in Celsius: "))
 convert = CelsiusToKelvin(tempInCelsius)
 print(str(convert.conversion()) + " Kelvin")
 convert = FahrenheitToCelsius(tempInCelsius)
 print(str(convert.conversion()) + "Fahrenheit")
 convert = CelsiusToFahrenheit(tempInCelsius)
 print(str(convert.conversion()) + "Fahrenheit")
 convert= KelvinToCelsius(tempInCelsius)
 print(str(convert.conversion()) + "Kelvin")

main()
