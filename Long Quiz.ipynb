# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexTomagan/OOP-58001/blob/main/Long%20Quiz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Write a Python program that asks the user to enter the radius of a circle and solve its area and perimeter.

# %%
r = float(input("Enter the radius of the circle:"))
print("The perimeter of the circle is", 2*3.14*r)

# %% [markdown]
# Create a class name Circle allowing you to build a circle with radius and pi attributes.

# %% [markdown]
# Create a Perimeter method to calculate the perimeter of the circle and an Area

# %% [markdown]
# Create a perimeter method to calculate the area of ​​the circle.

# %%
def findArea(r):
  PI-3.14
  return PI * (r*r);
print("Area of a circle = %.6f" % findArea(6));
# Out:
# Area of a circle = 113.040000
